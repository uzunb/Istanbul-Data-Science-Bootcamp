# %% [markdown]
# ## Preliminary Note

# %% [markdown]
# We ran a limited number of iterations in GPU mode because the configurations in this notebook took a long time in our training with the device=CPU parameter.
#
# The full training in CPU mode took about 12 hours.
#
# **If you want to do full training in CPU**
# * set ITERATION to 10000
# * set DEVICE to CPU

# %% [markdown]
# ## Imports

# %%
# %pip install nb_black

import warnings
from tqdm import tqdm
from pathlib import Path
from itertools import repeat

import numpy as np
import pandas as pd
from scipy.stats import skew

from sklearn.metrics import f1_score
from sklearn.model_selection import KFold, StratifiedKFold, StratifiedGroupKFold

import lightgbm as lgbm
from catboost import CatBoostClassifier, Pool
from catboost.utils import get_roc_curve, select_threshold

# %load_ext lab_black
warnings.filterwarnings("ignore")

pd.options.display.max_rows = 250
pd.options.display.max_columns = 250
# Out:
# Collecting nb_black
#   Downloading nb_black-1.0.7.tar.gz (4.8 kB)
# Requirement already satisfied: ipython in c:\users\batuhan\anaconda3\lib\site-packages (from nb_black) (7.29.0)
# Requirement already satisfied: black>='19.3' in c:\users\batuhan\anaconda3\lib\site-packages (from nb_black) (19.10b0)
# Requirement already satisfied: pathspec<1,>=0.6 in c:\users\batuhan\anaconda3\lib\site-packages (from black>='19.3'->nb_black) (0.7.0)
# Requirement already satisfied: regex in c:\users\batuhan\anaconda3\lib\site-packages (from black>='19.3'->nb_black) (2021.8.3)
# Requirement already satisfied: toml>=0.9.4 in c:\users\batuhan\anaconda3\lib\site-packages (from black>='19.3'->nb_black) (0.10.2)
# Requirement already satisfied: typed-ast>=1.4.0 in c:\users\batuhan\anaconda3\lib\site-packages (from black>='19.3'->nb_black) (1.4.3)
# Requirement already satisfied: appdirs in c:\users\batuhan\anaconda3\lib\site-packages (from black>='19.3'->nb_black) (1.4.4)
# Requirement already satisfied: click>=6.5 in c:\users\batuhan\anaconda3\lib\site-packages (from black>='19.3'->nb_black) (8.0.3)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\batuhan\anaconda3\lib\site-packages (from black>='19.3'->nb_black) (21.2.0)
# Requirement already satisfied: colorama in c:\users\batuhan\anaconda3\lib\site-packages (from click>=6.5->black>='19.3'->nb_black) (0.4.4)
# Requirement already satisfied: pygments in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (2.10.0)
# Requirement already satisfied: pickleshare in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (0.18.0)
# Requirement already satisfied: decorator in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (58.0.4)
# Requirement already satisfied: traitlets>=4.2 in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (5.1.0)
# Requirement already satisfied: backcall in c:\users\batuhan\anaconda3\lib\site-packages (from ipython->nb_black) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\batuhan\anaconda3\lib\site-packages (from jedi>=0.16->ipython->nb_black) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\batuhan\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->nb_black) (0.2.5)
# Building wheels for collected packages: nb-black
#   Building wheel for nb-black (setup.py): started
#   Building wheel for nb-black (setup.py): finished with status 'done'
#   Created wheel for nb-black: filename=nb_black-1.0.7-py3-none-any.whl size=5298 sha256=3094c6aebb916e316a3a7db4fbc7d4eb6c4bda38ffe806d8e70663eecd83bc87
#   Stored in directory: c:\users\batuhan\appdata\local\pip\cache\wheels\25\9d\fc\6312e3d8a66c164cc7f9d80bc66cc25de03a362a30b9f84aa3
# Successfully built nb-black
# Installing collected packages: nb-black
# Successfully installed nb-black-1.0.7
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/1552144716.py in <module>
#      14
#      15 import lightgbm as lgbm
# ---> 16 from catboost import CatBoostClassifier, Pool
#      17 from catboost.utils import get_roc_curve, select_threshold
#      18
#
# ModuleNotFoundError: No module named 'catboost'

# %% [markdown]
# ## Definitions

# %%
SEED = 42
FOLD_CNT = 9
sparsity_threshold = 0.0003

ITERATION = 1000
DEVICE = "GPU"

label = "ARTIS_DURUMU"
id_substr_list = ["ID"]
drop_cols = pd.Index(["POLICY_ID", "BASLANGIC_TARIHI"])
cat_col_diff = ["BASLANGIC_TARIHI", "GELIR"]
cat_col_union = []

sparse_categories = [
    "UYRUK",
    "MESLEK",
    "MESLEK_KIRILIM",
    "KAPSAM_TIPI",
    "DAGITIM_KANALI",
    "POLICE_SEHIR",
]

caterogical_cols = [
    "OFFICE_ID",
    "YATIRIM_KARAKTERI",
    "POLICE_SEHIR",
    "SIGORTA_TIP",
    "MUSTERI_SEGMENTI",
    "MESLEK_KIRILIM",
    "SOZLESME_KOKENI",
    "SOZLESME_KOKENI_DETAY",
    "KAPSAM_TIPI",
    "KAPSAM_GRUBU",
    "DAGITIM_KANALI",
    "uyruk_memleket",
    "dogumtarihi_cinsiyet",
    "meslek_medenihal_egitim",
    "dogumtarihi_meslek_medenihal",
    "sigortatip_kapsamtipi",
    "gelir_medenihal_egitim",
    "GELIR_qcut",
]

# %% [markdown]
# ## Preprocess Utilities

# %%
def preprocess_dataset(df_):

    df = df_.copy()

    df["GELIR"] = df["GELIR"].str.replace(",", ".").astype(float)
    df.loc[df["GELIR"] >= 20000, "GELIR"] = np.nan
    df.loc[df["GELIR"] <= 100, "GELIR"] = np.nan

    row_cnt, col_cnt = df.shape

    cat_col_diff = ["baslangic_tarihi"]
    cat_col_union = []

    train.dtypes[train.dtypes == "object"].index

    id_cols = (
        (df.nunique() == row_cnt).to_frame("is_matched").query("is_matched").index
    ).union(df.columns.str.contains("|".join(id_substr_list)))

    cat_cols = df.dtypes[df.dtypes == "object"].index.difference(
        id_cols.union(cat_col_diff)
    )

    df.loc[:, cat_cols] = df.loc[:, cat_cols].fillna("UNKNOWN").astype("category")
    return df


def replace_non_recurred_categorical_values(cat_col, train, test, inplace=True):
    train_vals = pd.Index(train[cat_col].unique())
    test_vals = pd.Index(test[cat_col].unique())

    exclude_vars = train_vals.union(test_vals).difference(train_vals.intersection(test_vals))

    replace_mappings = dict(
        zip(
            exclude_vars,
            repeat(np.nan),
        )
    )

    # print(" - ".join(map(str, exclude_vars)))

    if replace_mappings:
        train[cat_col] = train[cat_col].replace(replace_mappings)
        test[cat_col] = test[cat_col].replace(replace_mappings)

# %% [markdown]
# ## FE utilities

# %%
def extract_month_year(df):
    assert "BASLANGIC_TARIHI" in df.columns

    datetime_obj = pd.to_datetime(df.BASLANGIC_TARIHI)
    df["baslangic_month"] = datetime_obj.dt.month
    df["baslangic_year"] = datetime_obj.dt.year


def increase_features(df, cols, groupname=""):
    comparison_df = pd.DataFrame(
        np.argwhere(df[cols[1:]].values > df[cols[:-1]].values),
        columns=["index", "monthnum"],
    )
    df[groupname + "_increase_month_count"] = comparison_df.groupby("index")["monthnum"].count()
    df[groupname + "_increase_month_count"].fillna(0, inplace=True)
    
    df[groupname + "_increase_last_month"] = comparison_df.groupby("index")["monthnum"].max()
    df[groupname + "_increase_last_month"].fillna(-1, inplace=True)


def extract_tutar_stats(df, cols=[], groupname="None"):
    df[groupname + "_max"] = df[cols].max(axis=1)
    df[groupname + "_std"] = df[cols].std(axis=1)
    df[groupname + "_var"] = df[cols].var(axis=1)
    df[groupname + "_mad"] = df[cols].mad(axis=1)
    df[groupname + "_mean"] = df[cols].mean(axis=1)
    df[groupname + "_sum"] = df[cols].sum(axis=1)
    df[groupname + "_min"] = df[cols].min(axis=1)
    df[groupname + "_q05"] = df[cols].quantile(0.05, axis=1)
    df[groupname + "_q95"] = df[cols].quantile(0.95, axis=1)
    df[groupname + "_q25"] = df[cols].quantile(0.25, axis=1)
    df[groupname + "_q75"] = df[cols].quantile(0.75, axis=1)
    #     df[groupname+"_nunq"] = df[cols].nunique(axis=1)
    df[groupname + "_skew"] = df[cols].skew(axis=1)
    df[groupname + "_kurt"] = df[cols].kurt(axis=1)

# %% [markdown]
# ## Definitions

# %% [markdown]
# ## FE

# %%
def aggregate_catcols(df, to_group, comb_size):
    from itertools import combinations

    return pd.concat(
        [
            df.loc[:, grp.split(" - ")].astype(str).sum(axis=1).to_frame(grp)
            for idx, grp in enumerate(
                list(
                    map(
                        lambda x: " - ".join(x), list(
                            combinations(to_group, comb_size))
                    )
                )
            )
        ],
        axis=1,
    )

# %%
def extract_feature_expressions(df_):
    assert all(
        [
            col in df_.columns
            for col in [
                "baslangic_year",
                "DOGUM_TARIHI",
                "SENE_SONU_HESAP_DEGERI",
                "SENE_BASI_HESAP_DEGERI",
            ]
        ]
    )
    df = df_.copy()

    df["AGE_ON_POLICY_START"] = df["baslangic_year"] - df["DOGUM_TARIHI"]
    df["SENE_DEGER_FARKI"] = df["SENE_SONU_HESAP_DEGERI"] - df["SENE_BASI_HESAP_DEGERI"]
    # df["odeme_existence_count"] = (df[odenen_tutar_cols]>0).astype(int).sum(axis=1)

    return df

# %%
def extract_features(df_):
    df = df_.copy()

    assert all(
        [
            col in df_.columns
            for col in [
                "UYRUK",
                "MEMLEKET",
                "CINSIYET",
                "DOGUM_TARIHI",
                "MESLEK",
                "MEDENI_HAL",
                "EGITIM_DURUM",
                "SIGORTA_TIP",
                "KAPSAM_TIPI",
                "EKIM_ODENEN_TUTAR",
                "KASIM_ODENEN_TUTAR",
                "ARALIK_ODENEN_TUTAR",
            ]
        ]
    )

    GELIR_bins = [
        -np.inf,
        1000.0,
        1200.0,
        1800.0,
        2000.0,
        2500.0,
        3000.0,
        3500.0,
        5000.0,
        6000.0,
        np.inf,
    ]

    odenen_tutar_cols = [col for col in df_.columns if "ODENEN_TU" in col]
    vade_tutar_cols = [col for col in df_.columns if "VADE_TU" in col]

    extract_month_year(df)

    df["GELIR_qcut"] = pd.cut(df.GELIR, GELIR_bins)
    df["GELIR_qcut"] = df["GELIR_qcut"].cat.codes.astype(str).fillna("UNK")

    df["uyruk_memleket"] = df["UYRUK"].astype(str) + "_" + df["MEMLEKET"].astype(str)
    df["dogumtarihi_cinsiyet"] = (
        df["DOGUM_TARIHI"].astype(str) + "_" + df["CINSIYET"].astype(str)
    )
    df["meslek_medenihal_egitim"] = (
        df["MESLEK"].astype(str)
        + "_"
        + df["MEDENI_HAL"].astype(str)
        + "_"
        + df["EGITIM_DURUM"].astype(str)
    )
    df["dogumtarihi_meslek_medenihal"] = (
        df["DOGUM_TARIHI"].astype(str)
        + "_"
        + df["MESLEK"].astype(str)
        + "_"
        + df["MEDENI_HAL"].astype(str)
    )
    df["sigortatip_kapsamtipi"] = (
        df["SIGORTA_TIP"].astype(str) + "_" + df["KAPSAM_TIPI"].astype(str)
    )

    df["gelir_medenihal_egitim"] = (
        df["GELIR_qcut"].astype(str)
        + "_"
        + df["MEDENI_HAL"].astype(str)
        + "_"
        + df["EGITIM_DURUM"].astype(str)
    )

    increase_features(df, odenen_tutar_cols, "odenen")
    increase_features(df, vade_tutar_cols, "vade")

    extract_tutar_stats(df, odenen_tutar_cols, "odenen")
    extract_tutar_stats(df, vade_tutar_cols, "vade")

    df["odeme_existence_count"] = (df[odenen_tutar_cols] > 0).astype(int).sum(axis=1)

    df["odeme_diff_vade_max"] = (df[vade_tutar_cols].values - df[odenen_tutar_cols].values).max(axis=1)
    df["odeme_diff_vade_min"] = (df[vade_tutar_cols].values - df[odenen_tutar_cols].values).min(axis=1)
    df["odeme_diff_vade_std"] = (df[vade_tutar_cols].values - df[odenen_tutar_cols].values).std(axis=1)
    df["odeme_diff_vade_sum"] = (df[vade_tutar_cols].values - df[odenen_tutar_cols].values).sum(axis=1)

    # orneklem varyansı - varyans / mean
    # TODO: ask to author
    df["vade_std_mean_rat"] = df["vade_std"] / df["vade_mean"]

    df["last_three_month_sum_vade"] = df[["EKIM_VADE_TUTARI", "KASIM_VADE_TUTARI", "ARALIK_VADE_TUTARI"]].sum(axis=1)
    df["last_three_month_sum_odenen"] = df[["EKIM_ODENEN_TUTAR", "KASIM_ODENEN_TUTAR", "ARALIK_ODENEN_TUTAR"]].sum(axis=1)

    df.drop(
        ["UYRUK", "MEMLEKET", "CINSIYET", "MESLEK", "MEDENI_HAL", "EGITIM_DURUM"]
        + odenen_tutar_cols[:-3]
        + vade_tutar_cols,
        axis=1,
        inplace=True,
    )

    return df

# %% [markdown]
# ## I/O

# %%
# A routine to automatically map datasets contained in the Kaggle input folder to variables.
# For example, /kaggle/input/anadolu-hayat-emeklilik-datathon-coderspace/samplesubmission.csv --> samplesubmission

competition = "anadolu-hayat-emeklilik-datathon-coderspace"

INPUT_DIR = Path.home().parent / "kaggle" / "input"
OUTPUT_DIR = Path.home().parent / "kaggle" / "working"

for path in (INPUT_DIR / competition).iterdir():
    var_name, file_format = path.parts[-1].split(".")
    print(f"Assign data located in {path} to variable named {var_name}")
    exec(f'{var_name} = pd.read_{file_format}("{path}")')
# Out:
# Assign data located in /kaggle/input/anadolu-hayat-emeklilik-datathon-coderspace/samplesubmission.csv to variable named samplesubmission
# Assign data located in /kaggle/input/anadolu-hayat-emeklilik-datathon-coderspace/train.csv to variable named train
# Assign data located in /kaggle/input/anadolu-hayat-emeklilik-datathon-coderspace/test.csv to variable named test

# %% [markdown]
# ## Check dtypes & id_cols

# %%
row_cnt, col_cnt = train.shape

print(row_cnt, col_cnt)

id_cols = (
    (train.nunique() == row_cnt).to_frame("is_matched").query("is_matched").index
).union(train.columns[train.columns.str.contains("|".join(id_substr_list))])

print("Identifier columns are {}".format(", ".join(id_cols)))

cat_cols = train.dtypes[train.dtypes == "object"].index.difference(id_cols.union(cat_col_diff))
print("Categorical columns are {}".format(", ".join(cat_cols)))

drop_cols = drop_cols.union(id_cols)
# Out:
# 634112 49
# Identifier columns are OFFICE_ID, POLICY_ID
# Categorical columns are DAGITIM_KANALI, EGITIM_DURUM, KAPSAM_GRUBU, KAPSAM_TIPI, MEDENI_HAL, MESLEK, MESLEK_KIRILIM, POLICE_SEHIR, SOZLESME_KOKENI, SOZLESME_KOKENI_DETAY, UYRUK, YATIRIM_KARAKTERI

# %% [markdown]
# ## Feature Engineering

# %%
## Replace non-overlapping values to UNKNOWN placeholder(-1)
## For example, if "A" exists in training data for column UYRUK but not exists in test data, replace A to -1
## Apply this rule to all categorical columns to increase similarity neighborhood in sparse values.

for cat_col in cat_cols:
    replace_non_recurred_categorical_values(cat_col, train, test)
    # print(cat_col)

# Rare encoding

for sparse_category in sparse_categories:
    to_replace = list(
        train[sparse_category]
        .value_counts()[
            ((train[sparse_category].value_counts() / len(train)) < sparsity_threshold)
        ]
        .index
    )
    train[sparse_category].replace(to_replace=to_replace, value="-1", inplace=True)
    test[sparse_category].replace(to_replace=to_replace, value="-1", inplace=True)


train = extract_feature_expressions(extract_features(preprocess_dataset(train)))
test = extract_feature_expressions(extract_features(preprocess_dataset(test)))

# %%
train.shape
# Out:
# (634112, 71)

# %%
train.head(15).T
# Out:
#                                                  0                        1   \
# POLICY_ID                                   7203428                  2857821
# OFFICE_ID                                     10099                    10100
# SIGORTA_TIP                                       7                        7
# SOZLESME_KOKENI                                 NEW                      NEW
# SOZLESME_KOKENI_DETAY                           NEW                      NEW
# BASLANGIC_TARIHI                            2014-04                  2016-09
# KAPSAM_TIPI                              PENSION318               PENSION419
# KAPSAM_GRUBU                           STD B?REYSEL     KATILIM STD B?REYSEL
# DAGITIM_KANALI                               Kanal7          Kanal4 + Kanal2
# POLICE_SEHIR                              ESK??EH?R                BALIKES?R
# DOGUM_TARIHI                                   1964                     1966
# MESLEK_KIRILIM                              OCCU011                  UNKNOWN
# MUSTERI_SEGMENTI                              102.0                    103.0
# YATIRIM_KARAKTERI                           UNKNOWN                  UNKNOWN
# GELIR                                        2500.0                      NaN
# COCUK_SAYISI                                    2.0                      0.0
# EKIM_ODENEN_TUTAR                               220                      160
# KASIM_ODENEN_TUTAR                              220                      160
# ARALIK_ODENEN_TUTAR                             220                      160
# SENE_BASI_HESAP_DEGERI                     15248.75                  5842.71
# SENE_SONU_HESAP_DEGERI                     25684.25                 10104.56
# ARTIS_DURUMU                                      0                        0
# baslangic_month                                   4                        9
# baslangic_year                                 2014                     2016
# GELIR_qcut                                        4                       -1
# uyruk_memleket                                 TR_1                     TR_1
# dogumtarihi_cinsiyet                         1964_2                   1966_1
# meslek_medenihal_egitim       SEKT032_Single_Lisans  UNKNOWN_Married_UNKNOWN
# dogumtarihi_meslek_medenihal    1964_SEKT032_Single     1966_UNKNOWN_Married
# sigortatip_kapsamtipi                  7_PENSION318             7_PENSION419
# gelir_medenihal_egitim              4_Single_Lisans       -1_Married_UNKNOWN
# odenen_increase_month_count                     0.0                      0.0
# odenen_increase_last_month                     -1.0                     -1.0
# vade_increase_month_count                       0.0                      0.0
# vade_increase_last_month                       -1.0                     -1.0
# odenen_max                                      220                      160
# odenen_std                                      0.0                      0.0
# odenen_var                                      0.0                      0.0
# odenen_mad                                      0.0                      0.0
# odenen_mean                                   220.0                    160.0
# odenen_sum                                     2640                     1920
# odenen_min                                      220                      160
# odenen_q05                                    220.0                    160.0
# odenen_q95                                    220.0                    160.0
# odenen_q25                                    220.0                    160.0
# odenen_q75                                    220.0                    160.0
# odenen_skew                                     0.0                      0.0
# odenen_kurt                                     0.0                      0.0
# vade_max                                      220.0                    160.0
# vade_std                                        0.0                      0.0
# vade_var                                        0.0                      0.0
# vade_mad                                        0.0                      0.0
# vade_mean                                     220.0                    160.0
# vade_sum                                     2640.0                   1920.0
# vade_min                                      220.0                    160.0
# vade_q05                                      220.0                    160.0
# vade_q95                                      220.0                    160.0
# vade_q25                                      220.0                    160.0
# vade_q75                                      220.0                    160.0
# vade_skew                                       0.0                      0.0
# vade_kurt                                       0.0                      0.0
# odeme_existence_count                            12                       12
# odeme_diff_vade_max                             0.0                      0.0
# odeme_diff_vade_min                             0.0                      0.0
# odeme_diff_vade_std                             0.0                      0.0
# odeme_diff_vade_sum                             0.0                      0.0
# vade_std_mean_rat                               0.0                      0.0
# last_three_month_sum_vade                     660.0                    480.0
# last_three_month_sum_odenen                     660                      480
# AGE_ON_POLICY_START                              50                       50
# SENE_DEGER_FARKI                            10435.5                  4261.85
#
#                                                    2                       3   \
# POLICY_ID                                     7833031                 4474944
# OFFICE_ID                                       10042                   10056
# SIGORTA_TIP                                         1                       7
# SOZLESME_KOKENI                                   NEW                     NEW
# SOZLESME_KOKENI_DETAY                             NEW                     NEW
# BASLANGIC_TARIHI                              2016-07                 2014-09
# KAPSAM_TIPI                                PENSION250                      -1
# KAPSAM_GRUBU                                EV HANIMI            KATILIM GRUP
# DAGITIM_KANALI                        Kanal4 + Kanal2         Kanal4 + Kanal2
# POLICE_SEHIR                                BALIKES?R                  SAMSUN
# DOGUM_TARIHI                                     1956                    1977
# MESLEK_KIRILIM                                UNKNOWN                 OCCU039
# MUSTERI_SEGMENTI                                106.0                   102.0
# YATIRIM_KARAKTERI                             UNKNOWN                 UNKNOWN
# GELIR                                             NaN                  2500.0
# COCUK_SAYISI                                      0.0                     0.0
# EKIM_ODENEN_TUTAR                                 256                     150
# KASIM_ODENEN_TUTAR                                256                     150
# ARALIK_ODENEN_TUTAR                               256                     150
# SENE_BASI_HESAP_DEGERI                        3782.86                 6855.03
# SENE_SONU_HESAP_DEGERI                        7060.94                12645.25
# ARTIS_DURUMU                                        0                       0
# baslangic_month                                     7                       9
# baslangic_year                                   2016                    2014
# GELIR_qcut                                         -1                       4
# uyruk_memleket                                   TR_1                    TR_1
# dogumtarihi_cinsiyet                           1956_2                  1977_2
# meslek_medenihal_egitim       UNKNOWN_Married_UNKNOWN  SEKT032_Married_Lisans
# dogumtarihi_meslek_medenihal     1956_UNKNOWN_Married    1977_SEKT032_Married
# sigortatip_kapsamtipi                    1_PENSION250                    7_-1
# gelir_medenihal_egitim             -1_Married_UNKNOWN        4_Married_Lisans
# odenen_increase_month_count                       0.0                     1.0
# odenen_increase_last_month                       -1.0                     0.0
# vade_increase_month_count                         0.0                     1.0
# vade_increase_last_month                         -1.0                     0.0
# odenen_max                                        280                     150
# odenen_std                                   6.928203                5.773503
# odenen_var                                       48.0               33.333333
# odenen_mad                                   3.666667                3.055556
# odenen_mean                                     258.0              148.333333
# odenen_sum                                       3096                    1780
# odenen_min                                        256                     130
# odenen_q05                                      256.0                   141.0
# odenen_q95                                      266.8                   150.0
# odenen_q25                                      256.0                   150.0
# odenen_q75                                      256.0                   150.0
# odenen_skew                                  3.464102               -3.464102
# odenen_kurt                                      12.0                    12.0
# vade_max                                        280.0                   150.0
# vade_std                                     6.928203                5.773503
# vade_var                                         48.0               33.333333
# vade_mad                                     3.666667                3.055556
# vade_mean                                       258.0              148.333333
# vade_sum                                       3096.0                  1780.0
# vade_min                                        256.0                   130.0
# vade_q05                                        256.0                   141.0
# vade_q95                                        266.8                   150.0
# vade_q25                                        256.0                   150.0
# vade_q75                                        256.0                   150.0
# vade_skew                                    3.464102               -3.464102
# vade_kurt                                        12.0                    12.0
# odeme_existence_count                              12                      12
# odeme_diff_vade_max                               0.0                     0.0
# odeme_diff_vade_min                               0.0                     0.0
# odeme_diff_vade_std                               0.0                     0.0
# odeme_diff_vade_sum                               0.0                     0.0
# vade_std_mean_rat                            0.026854                0.038922
# last_three_month_sum_vade                       768.0                   450.0
# last_three_month_sum_odenen                       768                     450
# AGE_ON_POLICY_START                                60                      37
# SENE_DEGER_FARKI                              3278.08                 5790.22
#
#                                                   4                     5   \
# POLICY_ID                                    4660085               4736561
# OFFICE_ID                                      10068                 10168
# SIGORTA_TIP                                        7                     7
# SOZLESME_KOKENI                                  NEW                   NEW
# SOZLESME_KOKENI_DETAY                            NEW               NEW_MRG
# BASLANGIC_TARIHI                             2008-04               2010-08
# KAPSAM_TIPI                               PENSION100            PENSION059
# KAPSAM_GRUBU                                STD GRUP              STD GRUP
# DAGITIM_KANALI                       Kanal4 + Kanal2       Kanal4 + Kanal2
# POLICE_SEHIR                                ?STANBUL              ?STANBUL
# DOGUM_TARIHI                                    1962                  1978
# MESLEK_KIRILIM                               OCCU059               OCCU065
# MUSTERI_SEGMENTI                               102.0                 103.0
# YATIRIM_KARAKTERI                            UNKNOWN               UNKNOWN
# GELIR                                         5000.0                1600.0
# COCUK_SAYISI                                     0.0                   0.0
# EKIM_ODENEN_TUTAR                                100                   250
# KASIM_ODENEN_TUTAR                               100                   250
# ARALIK_ODENEN_TUTAR                              100                   250
# SENE_BASI_HESAP_DEGERI                      27837.75              46113.02
# SENE_SONU_HESAP_DEGERI                      31613.07              57644.05
# ARTIS_DURUMU                                       0                     1
# baslangic_month                                    4                     8
# baslangic_year                                  2008                  2010
# GELIR_qcut                                         7                     2
# uyruk_memleket                                  TR_1                  TR_1
# dogumtarihi_cinsiyet                          1962_2                1978_2
# meslek_medenihal_egitim       SEKT010_Married_Lisans  SEKT032_Married_Lise
# dogumtarihi_meslek_medenihal    1962_SEKT010_Married  1978_SEKT032_Married
# sigortatip_kapsamtipi                   7_PENSION100          7_PENSION059
# gelir_medenihal_egitim              7_Married_Lisans        2_Married_Lise
# odenen_increase_month_count                      0.0                   0.0
# odenen_increase_last_month                      -1.0                  -1.0
# vade_increase_month_count                        0.0                   0.0
# vade_increase_last_month                        -1.0                  -1.0
# odenen_max                                       100                   250
# odenen_std                                       0.0                   0.0
# odenen_var                                       0.0                   0.0
# odenen_mad                                       0.0                   0.0
# odenen_mean                                    100.0                 250.0
# odenen_sum                                      1200                  3000
# odenen_min                                       100                   250
# odenen_q05                                     100.0                 250.0
# odenen_q95                                     100.0                 250.0
# odenen_q25                                     100.0                 250.0
# odenen_q75                                     100.0                 250.0
# odenen_skew                                      0.0                   0.0
# odenen_kurt                                      0.0                   0.0
# vade_max                                       100.0                 250.0
# vade_std                                         0.0                   0.0
# vade_var                                         0.0                   0.0
# vade_mad                                         0.0                   0.0
# vade_mean                                      100.0                 250.0
# vade_sum                                      1200.0                3000.0
# vade_min                                       100.0                 250.0
# vade_q05                                       100.0                 250.0
# vade_q95                                       100.0                 250.0
# vade_q25                                       100.0                 250.0
# vade_q75                                       100.0                 250.0
# vade_skew                                        0.0                   0.0
# vade_kurt                                        0.0                   0.0
# odeme_existence_count                             12                    12
# odeme_diff_vade_max                              0.0                   0.0
# odeme_diff_vade_min                              0.0                   0.0
# odeme_diff_vade_std                              0.0                   0.0
# odeme_diff_vade_sum                              0.0                   0.0
# vade_std_mean_rat                                0.0                   0.0
# last_three_month_sum_vade                      300.0                 750.0
# last_three_month_sum_odenen                      300                   750
# AGE_ON_POLICY_START                               46                    32
# SENE_DEGER_FARKI                             3775.32              11531.03
#
#                                                   6                       7   \
# POLICY_ID                                    8167943                 2420140
# OFFICE_ID                                      10006                   10213
# SIGORTA_TIP                                        8                       1
# SOZLESME_KOKENI                                  NEW                     NEW
# SOZLESME_KOKENI_DETAY                            NEW                     NEW
# BASLANGIC_TARIHI                             2018-12                 2015-12
# KAPSAM_TIPI                                       -1              PENSION194
# KAPSAM_GRUBU                                     OKS               EV HANIMI
# DAGITIM_KANALI                       Kanal4 + Kanal2         Kanal4 + Kanal2
# POLICE_SEHIR                                ?STANBUL                 UNKNOWN
# DOGUM_TARIHI                                    1993                    1970
# MESLEK_KIRILIM                               UNKNOWN                 OCCU058
# MUSTERI_SEGMENTI                               102.0                   103.0
# YATIRIM_KARAKTERI                            UNKNOWN                 UNKNOWN
# GELIR                                            NaN                  1500.0
# COCUK_SAYISI                                     0.0                     0.0
# EKIM_ODENEN_TUTAR                                  0                     430
# KASIM_ODENEN_TUTAR                                 0                     430
# ARALIK_ODENEN_TUTAR                                0                     430
# SENE_BASI_HESAP_DEGERI                        407.26                19800.67
# SENE_SONU_HESAP_DEGERI                        462.37                26823.51
# ARTIS_DURUMU                                       0                       0
# baslangic_month                                   12                      12
# baslangic_year                                  2018                    2015
# GELIR_qcut                                        -1                       2
# uyruk_memleket                                  TR_1                    TR_1
# dogumtarihi_cinsiyet                          1993_1                  1970_2
# meslek_medenihal_egitim       UNKNOWN_Single_UNKNOWN  SEKT032_Single_UNKNOWN
# dogumtarihi_meslek_medenihal     1993_UNKNOWN_Single     1970_SEKT032_Single
# sigortatip_kapsamtipi                           8_-1            1_PENSION194
# gelir_medenihal_egitim             -1_Single_UNKNOWN        2_Single_UNKNOWN
# odenen_increase_month_count                      0.0                     0.0
# odenen_increase_last_month                      -1.0                    -1.0
# vade_increase_month_count                        0.0                     0.0
# vade_increase_last_month                        -1.0                    -1.0
# odenen_max                                         0                     430
# odenen_std                                       0.0                     0.0
# odenen_var                                       0.0                     0.0
# odenen_mad                                       0.0                     0.0
# odenen_mean                                      0.0                   430.0
# odenen_sum                                         0                    5160
# odenen_min                                         0                     430
# odenen_q05                                       0.0                   430.0
# odenen_q95                                       0.0                   430.0
# odenen_q25                                       0.0                   430.0
# odenen_q75                                       0.0                   430.0
# odenen_skew                                      0.0                     0.0
# odenen_kurt                                      0.0                     0.0
# vade_max                                       120.0                   430.0
# vade_std                                         0.0                     0.0
# vade_var                                         0.0                     0.0
# vade_mad                                         0.0                     0.0
# vade_mean                                      120.0                   430.0
# vade_sum                                      1440.0                  5160.0
# vade_min                                       120.0                   430.0
# vade_q05                                       120.0                   430.0
# vade_q95                                       120.0                   430.0
# vade_q25                                       120.0                   430.0
# vade_q75                                       120.0                   430.0
# vade_skew                                        0.0                     0.0
# vade_kurt                                        0.0                     0.0
# odeme_existence_count                              0                      12
# odeme_diff_vade_max                            120.0                     0.0
# odeme_diff_vade_min                            120.0                     0.0
# odeme_diff_vade_std                              0.0                     0.0
# odeme_diff_vade_sum                           1440.0                     0.0
# vade_std_mean_rat                                0.0                     0.0
# last_three_month_sum_vade                      360.0                  1290.0
# last_three_month_sum_odenen                        0                    1290
# AGE_ON_POLICY_START                               25                      45
# SENE_DEGER_FARKI                               55.11                 7022.84
#
#                                                    8                    9   \
# POLICY_ID                                     5548250              1127870
# OFFICE_ID                                       10222                10230
# SIGORTA_TIP                                         1                    6
# SOZLESME_KOKENI                                   NEW                  NEW
# SOZLESME_KOKENI_DETAY                             NEW                  NEW
# BASLANGIC_TARIHI                              2017-01              2016-02
# KAPSAM_TIPI                                PENSION250           PENSION028
# KAPSAM_GRUBU                                EV HANIMI             STD GRUP
# DAGITIM_KANALI                        Kanal4 + Kanal2      Kanal4 + Kanal2
# POLICE_SEHIR                                 NEV?EH?R               ANKARA
# DOGUM_TARIHI                                     1965                 1993
# MESLEK_KIRILIM                                OCCU037              OCCU006
# MUSTERI_SEGMENTI                                105.0                106.0
# YATIRIM_KARAKTERI                             UNKNOWN              UNKNOWN
# GELIR                                          1000.0                  NaN
# COCUK_SAYISI                                      0.0                  0.0
# EKIM_ODENEN_TUTAR                                 280                    0
# KASIM_ODENEN_TUTAR                                280                    0
# ARALIK_ODENEN_TUTAR                               280                    0
# SENE_BASI_HESAP_DEGERI                        9333.31               501.96
# SENE_SONU_HESAP_DEGERI                       13690.83               519.72
# ARTIS_DURUMU                                        0                    0
# baslangic_month                                     1                    2
# baslangic_year                                   2017                 2016
# GELIR_qcut                                          0                   -1
# uyruk_memleket                                   TR_1                 TR_1
# dogumtarihi_cinsiyet                           1965_2               1993_1
# meslek_medenihal_egitim       SEKT032_Married_UNKNOWN  SEKT032_Single_Lise
# dogumtarihi_meslek_medenihal     1965_SEKT032_Married  1993_SEKT032_Single
# sigortatip_kapsamtipi                    1_PENSION250         6_PENSION028
# gelir_medenihal_egitim              0_Married_UNKNOWN       -1_Single_Lise
# odenen_increase_month_count                       0.0                  0.0
# odenen_increase_last_month                       -1.0                 -1.0
# vade_increase_month_count                         0.0                  0.0
# vade_increase_last_month                         -1.0                 -1.0
# odenen_max                                        280                    0
# odenen_std                                        0.0                  0.0
# odenen_var                                        0.0                  0.0
# odenen_mad                                        0.0                  0.0
# odenen_mean                                     280.0                  0.0
# odenen_sum                                       3360                    0
# odenen_min                                        280                    0
# odenen_q05                                      280.0                  0.0
# odenen_q95                                      280.0                  0.0
# odenen_q25                                      280.0                  0.0
# odenen_q75                                      280.0                  0.0
# odenen_skew                                       0.0                  0.0
# odenen_kurt                                       0.0                  0.0
# vade_max                                        280.0                 97.0
# vade_std                                          0.0                  0.0
# vade_var                                          0.0                  0.0
# vade_mad                                          0.0                  0.0
# vade_mean                                       280.0                 97.0
# vade_sum                                       3360.0               1164.0
# vade_min                                        280.0                 97.0
# vade_q05                                        280.0                 97.0
# vade_q95                                        280.0                 97.0
# vade_q25                                        280.0                 97.0
# vade_q75                                        280.0                 97.0
# vade_skew                                         0.0                  0.0
# vade_kurt                                         0.0                  0.0
# odeme_existence_count                              12                    0
# odeme_diff_vade_max                               0.0                 97.0
# odeme_diff_vade_min                               0.0                 97.0
# odeme_diff_vade_std                               0.0                  0.0
# odeme_diff_vade_sum                               0.0               1164.0
# vade_std_mean_rat                                 0.0                  0.0
# last_three_month_sum_vade                       840.0                291.0
# last_three_month_sum_odenen                       840                    0
# AGE_ON_POLICY_START                                52                   23
# SENE_DEGER_FARKI                              4357.52                17.76
#
#                                                    10                     11  \
# POLICY_ID                                     8216966                6218600
# OFFICE_ID                                       10232                  10234
# SIGORTA_TIP                                         7                      7
# SOZLESME_KOKENI                                   NEW                    NEW
# SOZLESME_KOKENI_DETAY                             NEW                    NEW
# BASLANGIC_TARIHI                              2015-08                2007-03
# KAPSAM_TIPI                                        -1             PENSION101
# KAPSAM_GRUBU                                     GRUP               STD GRUP
# DAGITIM_KANALI                        Kanal4 + Kanal2        Kanal1 + Kanal2
# POLICE_SEHIR                                BALIKES?R                 MAN?SA
# DOGUM_TARIHI                                     1987                   1974
# MESLEK_KIRILIM                                OCCU006                OCCU069
# MUSTERI_SEGMENTI                                103.0                  103.0
# YATIRIM_KARAKTERI                             UNKNOWN               Dikkatli
# GELIR                                          1500.0                    NaN
# COCUK_SAYISI                                      0.0                    1.0
# EKIM_ODENEN_TUTAR                                   0                    430
# KASIM_ODENEN_TUTAR                                  0                    430
# ARALIK_ODENEN_TUTAR                                 0                    430
# SENE_BASI_HESAP_DEGERI                         127.94               52602.37
# SENE_SONU_HESAP_DEGERI                         142.98               62212.81
# ARTIS_DURUMU                                        0                      1
# baslangic_month                                     8                      3
# baslangic_year                                   2015                   2007
# GELIR_qcut                                          2                     -1
# uyruk_memleket                                   TR_1                   TR_1
# dogumtarihi_cinsiyet                           1987_2                 1974_1
# meslek_medenihal_egitim       SEKT032_Married_UNKNOWN  SEKT019_Single_Lisans
# dogumtarihi_meslek_medenihal     1987_SEKT032_Married    1974_SEKT019_Single
# sigortatip_kapsamtipi                            7_-1           7_PENSION101
# gelir_medenihal_egitim              2_Married_UNKNOWN       -1_Single_Lisans
# odenen_increase_month_count                       0.0                    0.0
# odenen_increase_last_month                       -1.0                   -1.0
# vade_increase_month_count                         0.0                    0.0
# vade_increase_last_month                         -1.0                   -1.0
# odenen_max                                          0                    430
# odenen_std                                        0.0                    0.0
# odenen_var                                        0.0                    0.0
# odenen_mad                                        0.0                    0.0
# odenen_mean                                       0.0                  430.0
# odenen_sum                                          0                   5160
# odenen_min                                          0                    430
# odenen_q05                                        0.0                  430.0
# odenen_q95                                        0.0                  430.0
# odenen_q25                                        0.0                  430.0
# odenen_q75                                        0.0                  430.0
# odenen_skew                                       0.0                    0.0
# odenen_kurt                                       0.0                    0.0
# vade_max                                         60.0                  430.0
# vade_std                                          0.0                    0.0
# vade_var                                          0.0                    0.0
# vade_mad                                          0.0                    0.0
# vade_mean                                        60.0                  430.0
# vade_sum                                        720.0                 5160.0
# vade_min                                         60.0                  430.0
# vade_q05                                         60.0                  430.0
# vade_q95                                         60.0                  430.0
# vade_q25                                         60.0                  430.0
# vade_q75                                         60.0                  430.0
# vade_skew                                         0.0                    0.0
# vade_kurt                                         0.0                    0.0
# odeme_existence_count                               0                     12
# odeme_diff_vade_max                              60.0                    0.0
# odeme_diff_vade_min                              60.0                    0.0
# odeme_diff_vade_std                               0.0                    0.0
# odeme_diff_vade_sum                             720.0                    0.0
# vade_std_mean_rat                                 0.0                    0.0
# last_three_month_sum_vade                       180.0                 1290.0
# last_three_month_sum_odenen                         0                   1290
# AGE_ON_POLICY_START                                28                     33
# SENE_DEGER_FARKI                                15.04                9610.44
#
#                                                       12  \
# POLICY_ID                                        1831063
# OFFICE_ID                                          10238
# SIGORTA_TIP                                            1
# SOZLESME_KOKENI                                      NEW
# SOZLESME_KOKENI_DETAY                                NEW
# BASLANGIC_TARIHI                                 2013-03
# KAPSAM_TIPI                                   PENSION194
# KAPSAM_GRUBU                                   EV HANIMI
# DAGITIM_KANALI                           Kanal4 + Kanal2
# POLICE_SEHIR                                     KOCAEL?
# DOGUM_TARIHI                                        1969
# MESLEK_KIRILIM                                   OCCU037
# MUSTERI_SEGMENTI                                   103.0
# YATIRIM_KARAKTERI                                UNKNOWN
# GELIR                                              700.0
# COCUK_SAYISI                                         0.0
# EKIM_ODENEN_TUTAR                                   1500
# KASIM_ODENEN_TUTAR                                  1500
# ARALIK_ODENEN_TUTAR                                 1500
# SENE_BASI_HESAP_DEGERI                          91370.23
# SENE_SONU_HESAP_DEGERI                         165966.24
# ARTIS_DURUMU                                           1
# baslangic_month                                        3
# baslangic_year                                      2013
# GELIR_qcut                                             0
# uyruk_memleket                                      TR_1
# dogumtarihi_cinsiyet                              1969_2
# meslek_medenihal_egitim       SEKT008_Married_?lkö?retim
# dogumtarihi_meslek_medenihal        1969_SEKT008_Married
# sigortatip_kapsamtipi                       1_PENSION194
# gelir_medenihal_egitim              0_Married_?lkö?retim
# odenen_increase_month_count                          0.0
# odenen_increase_last_month                          -1.0
# vade_increase_month_count                            0.0
# vade_increase_last_month                            -1.0
# odenen_max                                          1500
# odenen_std                                           0.0
# odenen_var                                           0.0
# odenen_mad                                           0.0
# odenen_mean                                       1500.0
# odenen_sum                                         18000
# odenen_min                                          1500
# odenen_q05                                        1500.0
# odenen_q95                                        1500.0
# odenen_q25                                        1500.0
# odenen_q75                                        1500.0
# odenen_skew                                          0.0
# odenen_kurt                                          0.0
# vade_max                                          1500.0
# vade_std                                             0.0
# vade_var                                             0.0
# vade_mad                                             0.0
# vade_mean                                         1500.0
# vade_sum                                         18000.0
# vade_min                                          1500.0
# vade_q05                                          1500.0
# vade_q95                                          1500.0
# vade_q25                                          1500.0
# vade_q75                                          1500.0
# vade_skew                                            0.0
# vade_kurt                                            0.0
# odeme_existence_count                                 12
# odeme_diff_vade_max                                  0.0
# odeme_diff_vade_min                                  0.0
# odeme_diff_vade_std                                  0.0
# odeme_diff_vade_sum                                  0.0
# vade_std_mean_rat                                    0.0
# last_three_month_sum_vade                         4500.0
# last_three_month_sum_odenen                         4500
# AGE_ON_POLICY_START                                   44
# SENE_DEGER_FARKI                                74596.01
#
#                                                 13                    14
# POLICY_ID                                  8691355               3628583
# OFFICE_ID                                    10129                 10238
# SIGORTA_TIP                                      1                     1
# SOZLESME_KOKENI                                NEW                   NEW
# SOZLESME_KOKENI_DETAY                          NEW                   NEW
# BASLANGIC_TARIHI                           2006-03               2016-12
# KAPSAM_TIPI                             PENSION056            PENSION250
# KAPSAM_GRUBU                             EV HANIMI             EV HANIMI
# DAGITIM_KANALI                     Kanal4 + Kanal2       Kanal4 + Kanal2
# POLICE_SEHIR                                 ?ZM?R               KOCAEL?
# DOGUM_TARIHI                                  1981                  1984
# MESLEK_KIRILIM                             OCCU037               OCCU006
# MUSTERI_SEGMENTI                             106.0                 104.0
# YATIRIM_KARAKTERI                          UNKNOWN               UNKNOWN
# GELIR                                          NaN                2500.0
# COCUK_SAYISI                                   0.0                   0.0
# EKIM_ODENEN_TUTAR                                0                   310
# KASIM_ODENEN_TUTAR                               0                   310
# ARALIK_ODENEN_TUTAR                              0                   310
# SENE_BASI_HESAP_DEGERI                         0.0              12966.17
# SENE_SONU_HESAP_DEGERI                         0.0              23912.78
# ARTIS_DURUMU                                     1                     1
# baslangic_month                                  3                    12
# baslangic_year                                2006                  2016
# GELIR_qcut                                      -1                     4
# uyruk_memleket                                TR_1                  TR_1
# dogumtarihi_cinsiyet                        1981_2                1984_2
# meslek_medenihal_egitim       SEKT010_Married_Lise  SEKT010_Married_Lise
# dogumtarihi_meslek_medenihal  1981_SEKT010_Married  1984_SEKT010_Married
# sigortatip_kapsamtipi                 1_PENSION056          1_PENSION250
# gelir_medenihal_egitim             -1_Married_Lise        4_Married_Lise
# odenen_increase_month_count                    0.0                   0.0
# odenen_increase_last_month                    -1.0                  -1.0
# vade_increase_month_count                      0.0                   0.0
# vade_increase_last_month                      -1.0                  -1.0
# odenen_max                                       0                   310
# odenen_std                                     0.0                   0.0
# odenen_var                                     0.0                   0.0
# odenen_mad                                     0.0                   0.0
# odenen_mean                                    0.0                 310.0
# odenen_sum                                       0                  3720
# odenen_min                                       0                   310
# odenen_q05                                     0.0                 310.0
# odenen_q95                                     0.0                 310.0
# odenen_q25                                     0.0                 310.0
# odenen_q75                                     0.0                 310.0
# odenen_skew                                    0.0                   0.0
# odenen_kurt                                    0.0                   0.0
# vade_max                                     130.0                 310.0
# vade_std                                       0.0                   0.0
# vade_var                                       0.0                   0.0
# vade_mad                                       0.0                   0.0
# vade_mean                                    130.0                 310.0
# vade_sum                                    1560.0                3720.0
# vade_min                                     130.0                 310.0
# vade_q05                                     130.0                 310.0
# vade_q95                                     130.0                 310.0
# vade_q25                                     130.0                 310.0
# vade_q75                                     130.0                 310.0
# vade_skew                                      0.0                   0.0
# vade_kurt                                      0.0                   0.0
# odeme_existence_count                            0                    12
# odeme_diff_vade_max                          130.0                   0.0
# odeme_diff_vade_min                          130.0                   0.0
# odeme_diff_vade_std                            0.0                   0.0
# odeme_diff_vade_sum                         1560.0                   0.0
# vade_std_mean_rat                              0.0                   0.0
# last_three_month_sum_vade                    390.0                 930.0
# last_three_month_sum_odenen                      0                   930
# AGE_ON_POLICY_START                             25                    32
# SENE_DEGER_FARKI                               0.0              10946.61

# %% [markdown]
# ## Modelling

# %%
cat_features = list(
    cat_cols.intersection(train.columns).union(
        train.dtypes[train.dtypes == object].index
    )
)

feat_cols = list(train.columns.difference(drop_cols.union([label])))

print("Categorical columns after categorical FE are {}".format(", ".join(cat_features)))
print(
    "Length of categorical columns after categorical FE are {}".format(
        len(cat_features)
    )
)

params = dict(
    allow_writing_files=False,
    cat_features=cat_features,
    iterations=ITERATION,
    random_state=SEED,
    scale_pos_weight=4.25,
    early_stopping_rounds=1000,
    depth=7,
    learning_rate=0.06,
    max_ctr_complexity=6,
    eval_metric="F1:use_weights=False",
    task_type=DEVICE,
    devices="0:1",
)
# Out:
# Categorical columns after categorical FE are DAGITIM_KANALI, GELIR_qcut, KAPSAM_GRUBU, KAPSAM_TIPI, MESLEK_KIRILIM, POLICE_SEHIR, SOZLESME_KOKENI, SOZLESME_KOKENI_DETAY, YATIRIM_KARAKTERI, dogumtarihi_cinsiyet, dogumtarihi_meslek_medenihal, gelir_medenihal_egitim, meslek_medenihal_egitim, sigortatip_kapsamtipi, uyruk_memleket
# Length of categorical columns after categorical FE are 15

# %%
f1_errs = []
models = []

# %%
cv = StratifiedKFold(n_splits=FOLD_CNT, shuffle=True, random_state=SEED)
cv_splits = list(cv.split(train.index, train[label]))

# %%
for split_train, split_val in tqdm(cv_splits):

    model = CatBoostClassifier(
        **params,
    )

    model.fit(
        train.loc[split_train, feat_cols],
        train.loc[split_train, label],
        eval_set=(
            train.loc[split_val, feat_cols],
            train.loc[split_val, label],
        ),
        verbose=25,
    )

    preds = model.predict(train.loc[split_val, feat_cols])
    f1_err = f1_score(train.loc[split_val, label], preds)
    f1_errs.append(f1_err)
    models.append(model)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# 0:	learn: 0.4013476	test: 0.3986121	best: 0.3986121 (0)	total: 122ms	remaining: 2m 1s
# 25:	learn: 0.4104774	test: 0.4064133	best: 0.4064133 (25)	total: 2.69s	remaining: 1m 40s
# 50:	learn: 0.4224244	test: 0.4195467	best: 0.4196340 (48)	total: 5.22s	remaining: 1m 37s
# 75:	learn: 0.4287491	test: 0.4288715	best: 0.4288715 (75)	total: 7.71s	remaining: 1m 33s
# 100:	learn: 0.4345968	test: 0.4347524	best: 0.4357565 (96)	total: 10.6s	remaining: 1m 33s
# 125:	learn: 0.4411278	test: 0.4427895	best: 0.4434408 (122)	total: 13s	remaining: 1m 30s
# 150:	learn: 0.4458514	test: 0.4479588	best: 0.4479588 (150)	total: 15.5s	remaining: 1m 27s
# 175:	learn: 0.4483134	test: 0.4494226	best: 0.4495930 (174)	total: 18s	remaining: 1m 24s
# 200:	learn: 0.4499800	test: 0.4512399	best: 0.4512399 (200)	total: 20.8s	remaining: 1m 22s
# 225:	learn: 0.4527835	test: 0.4538343	best: 0.4546853 (220)	total: 24.3s	remaining: 1m 23s
# 250:	learn: 0.4551282	test: 0.4562386	best: 0.4563242 (246)	total: 26.8s	remaining: 1m 19s
# 275:	learn: 0.4578733	test: 0.4588805	best: 0.4589335 (273)	total: 29.3s	remaining: 1m 16s
# 300:	learn: 0.4601942	test: 0.4612790	best: 0.4615385 (298)	total: 32.1s	remaining: 1m 14s
# 325:	learn: 0.4625311	test: 0.4608250	best: 0.4615385 (298)	total: 34.5s	remaining: 1m 11s
# 350:	learn: 0.4638713	test: 0.4628146	best: 0.4628146 (350)	total: 37.1s	remaining: 1m 8s
# 375:	learn: 0.4658034	test: 0.4635163	best: 0.4641923 (365)	total: 39.6s	remaining: 1m 5s
# 400:	learn: 0.4674225	test: 0.4657476	best: 0.4657476 (400)	total: 42.5s	remaining: 1m 3s
# 425:	learn: 0.4692192	test: 0.4662655	best: 0.4665156 (417)	total: 44.9s	remaining: 1m
# 450:	learn: 0.4708191	test: 0.4671823	best: 0.4672154 (447)	total: 47.4s	remaining: 57.7s
# 475:	learn: 0.4726039	test: 0.4683994	best: 0.4686745 (474)	total: 49.9s	remaining: 54.9s
# 500:	learn: 0.4741646	test: 0.4688655	best: 0.4688655 (500)	total: 52.5s	remaining: 52.3s
# 525:	learn: 0.4756784	test: 0.4703622	best: 0.4708562 (517)	total: 56s	remaining: 50.5s
# 550:	learn: 0.4774307	test: 0.4719293	best: 0.4726027 (546)	total: 58.7s	remaining: 47.9s
# 575:	learn: 0.4789695	test: 0.4723074	best: 0.4727687 (573)	total: 1m 1s	remaining: 45.1s
# 875:	learn: 0.4979363	test: 0.4700375	best: 0.4717646 (844)	total: 1m 31s	remaining: 13s
# 900:	learn: 0.4991568	test: 0.4710547	best: 0.4717646 (844)	total: 1m 34s	remaining: 10.4s
# 925:	learn: 0.5005849	test: 0.4721520	best: 0.4724512 (921)	total: 1m 37s	remaining: 7.79s
# 950:	learn: 0.5017417	test: 0.4735279	best: 0.4738863 (939)	total: 1m 41s	remaining: 5.21s
# 975:	learn: 0.5029866	test: 0.4723611	best: 0.4740923 (960)	total: 1m 43s	remaining: 2.55s
# 999:	learn: 0.5041055	test: 0.4740387	best: 0.4740923 (960)	total: 1m 46s	remaining: 0us
# bestTest = 0.4740923255
# bestIteration = 960
# Shrink model to first 961 iterations.
#  89%|████████▉ | 8/9 [18:26<02:08, 128.86s/it]
# 0:	learn: 0.3989897	test: 0.4084607	best: 0.4084607 (0)	total: 97.6ms	remaining: 1m 37s
# 25:	learn: 0.4099191	test: 0.4187120	best: 0.4187120 (25)	total: 2.9s	remaining: 1m 48s
# 50:	learn: 0.4215826	test: 0.4313616	best: 0.4314414 (48)	total: 5.97s	remaining: 1m 51s
# 75:	learn: 0.4281233	test: 0.4372267	best: 0.4379167 (74)	total: 8.97s	remaining: 1m 49s
# 100:	learn: 0.4357804	test: 0.4467363	best: 0.4472755 (98)	total: 11.4s	remaining: 1m 41s
# 125:	learn: 0.4403481	test: 0.4503475	best: 0.4506152 (116)	total: 14.2s	remaining: 1m 38s
# 150:	learn: 0.4428928	test: 0.4531078	best: 0.4532379 (145)	total: 16.8s	remaining: 1m 34s
# 175:	learn: 0.4462608	test: 0.4566897	best: 0.4569263 (174)	total: 19.3s	remaining: 1m 30s
# 200:	learn: 0.4487066	test: 0.4580015	best: 0.4584400 (192)	total: 21.7s	remaining: 1m 26s
# 225:	learn: 0.4513095	test: 0.4599695	best: 0.4601942 (224)	total: 24.2s	remaining: 1m 22s
# 250:	learn: 0.4539520	test: 0.4636294	best: 0.4636294 (250)	total: 27s	remaining: 1m 20s
# 275:	learn: 0.4566065	test: 0.4663696	best: 0.4664301 (272)	total: 29.5s	remaining: 1m 17s
# 300:	learn: 0.4594963	test: 0.4691203	best: 0.4691203 (300)	total: 32s	remaining: 1m 14s
# 325:	learn: 0.4610239	test: 0.4695275	best: 0.4702190 (311)	total: 34.5s	remaining: 1m 11s
# 350:	learn: 0.4629667	test: 0.4716994	best: 0.4721114 (344)	total: 37.5s	remaining: 1m 9s
# 375:	learn: 0.4647786	test: 0.4722611	best: 0.4723428 (367)	total: 41s	remaining: 1m 8s
# 400:	learn: 0.4665187	test: 0.4730942	best: 0.4734963 (395)	total: 43.5s	remaining: 1m 4s
# 425:	learn: 0.4682035	test: 0.4735474	best: 0.4740907 (421)	total: 46s	remaining: 1m 1s
# 450:	learn: 0.4705686	test: 0.4751335	best: 0.4755362 (436)	total: 48.8s	remaining: 59.4s
# 475:	learn: 0.4724476	test: 0.4756940	best: 0.4760833 (454)	total: 51.3s	remaining: 56.5s
# 500:	learn: 0.4740539	test: 0.4744736	best: 0.4761502 (480)	total: 53.7s	remaining: 53.5s
# 525:	learn: 0.4755075	test: 0.4750741	best: 0.4761502 (480)	total: 56.2s	remaining: 50.7s
# 550:	learn: 0.4772755	test: 0.4764930	best: 0.4768025 (538)	total: 59.1s	remaining: 48.1s
# 575:	learn: 0.4788892	test: 0.4765741	best: 0.4770720 (559)	total: 1m 1s	remaining: 45.3s
# 600:	learn: 0.4803724	test: 0.4770396	best: 0.4779963 (596)	total: 1m 4s	remaining: 42.5s
# 625:	learn: 0.4818463	test: 0.4777385	best: 0.4781226 (621)	total: 1m 6s	remaining: 39.8s
# 650:	learn: 0.4834267	test: 0.4783593	best: 0.4785745 (648)	total: 1m 9s	remaining: 37.3s
# 675:	learn: 0.4849581	test: 0.4783686	best: 0.4785745 (648)	total: 1m 13s	remaining: 35s
# 700:	learn: 0.4862355	test: 0.4783625	best: 0.4787475 (696)	total: 1m 15s	remaining: 32.2s
# 725:	learn: 0.4876926	test: 0.4788154	best: 0.4789571 (708)	total: 1m 18s	remaining: 29.5s
# 750:	learn: 0.4892677	test: 0.4784180	best: 0.4789571 (708)	total: 1m 20s	remaining: 26.8s
# 775:	learn: 0.4902215	test: 0.4780696	best: 0.4789571 (708)	total: 1m 23s	remaining: 24s
# 800:	learn: 0.4914627	test: 0.4776247	best: 0.4789571 (708)	total: 1m 25s	remaining: 21.3s
# 825:	learn: 0.4927724	test: 0.4781092	best: 0.4789571 (708)	total: 1m 28s	remaining: 18.6s
# 850:	learn: 0.4940305	test: 0.4778244	best: 0.4789571 (708)	total: 1m 30s	remaining: 15.9s
# 875:	learn: 0.4958548	test: 0.4773909	best: 0.4789571 (708)	total: 1m 33s	remaining: 13.2s
# 900:	learn: 0.4973640	test: 0.4794178	best: 0.4796006 (899)	total: 1m 36s	remaining: 10.6s
# 925:	learn: 0.4982009	test: 0.4792113	best: 0.4796006 (899)	total: 1m 38s	remaining: 7.88s
# 950:	learn: 0.4993205	test: 0.4804293	best: 0.4804293 (950)	total: 1m 41s	remaining: 5.22s
# 975:	learn: 0.5005818	test: 0.4801088	best: 0.4804461 (955)	total: 1m 44s	remaining: 2.57s
# 999:	learn: 0.5021767	test: 0.4796795	best: 0.4804461 (955)	total: 1m 47s	remaining: 0us
# bestTest = 0.4804461285
# bestIteration = 955
# Shrink model to first 956 iterations.
# 100%|██████████| 9/9 [20:32<00:00, 136.97s/it]

# %%
f1_errs
# Out:
# [0.4770721828439173,
#  0.48059894895975813,
#  0.4748201438848921,
#  0.4837116059282594,
#  0.47711711711711713,
#  0.46793958392704477,
#  0.4847317351598174,
#  0.4740923255308356,
#  0.4804461285479374]

# %%
(np.array(f1_errs).mean(), np.array(f1_errs).std())
# Out:
# (0.47783664132217546, 0.004929168395967689)

# %% [markdown]
# ## **Fold thresholding**

# %%
f1_errs = []
test_preds = []
fold_thresholds = []

thresholds = np.arange(0.3, 0.7, 0.0025)

for idx, (split_train, split_val) in enumerate(tqdm(cv_splits)):

    proba = models[idx].predict_proba(train.loc[split_val, feat_cols])[:, 1]

    scores = []

    for t in thresholds:
        scores.append(f1_score(train.loc[split_val, label], proba >= t))
    ix = np.argmax(scores)

    print("Threshold=%.3f, F-Score=%.5f" % (thresholds[ix], scores[ix]))

    f1_err = f1_score(
        train.loc[split_val, label], (proba >= thresholds[ix]).astype(int)
    )

    print("F1 w/ selected threshold:", f1_err)

    # f1_err = f1_score(test_y, preds)
    f1_errs.append(f1_err)

    test_preds.append(models[idx].predict_proba(test.loc[:, feat_cols])[:, 1])
    fold_thresholds.append(thresholds[ix])
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Threshold=0.520, F-Score=0.48207
# F1 w/ selected threshold: 0.4820692812452312
#  11%|█         | 1/9 [00:12<01:43, 12.97s/it]
# Threshold=0.535, F-Score=0.48221
# F1 w/ selected threshold: 0.48220598633042655
#  22%|██▏       | 2/9 [00:27<01:36, 13.84s/it]
# Threshold=0.545, F-Score=0.47772
# F1 w/ selected threshold: 0.47772012190099666
#  33%|███▎      | 3/9 [00:40<01:20, 13.45s/it]
# Threshold=0.543, F-Score=0.48792
# F1 w/ selected threshold: 0.48792231763100874
#  44%|████▍     | 4/9 [00:53<01:07, 13.46s/it]
# Threshold=0.560, F-Score=0.48026
# F1 w/ selected threshold: 0.48026260415789923
#  56%|█████▌    | 5/9 [01:06<00:52, 13.18s/it]
# Threshold=0.535, F-Score=0.47119
# F1 w/ selected threshold: 0.4711877695021561
#  67%|██████▋   | 6/9 [01:19<00:38, 13.00s/it]
# Threshold=0.543, F-Score=0.48814
# F1 w/ selected threshold: 0.48814371257485034
#  78%|███████▊  | 7/9 [01:33<00:26, 13.31s/it]
# Threshold=0.548, F-Score=0.47581
# F1 w/ selected threshold: 0.4758084322554237
#  89%|████████▉ | 8/9 [01:46<00:13, 13.23s/it]
# Threshold=0.568, F-Score=0.48875
# F1 w/ selected threshold: 0.4887525562372188
# 100%|██████████| 9/9 [01:59<00:00, 13.31s/it]

# %%
f1_errs
# Out:
# [0.4820692812452312,
#  0.48220598633042655,
#  0.47772012190099666,
#  0.48792231763100874,
#  0.48026260415789923,
#  0.4711877695021561,
#  0.48814371257485034,
#  0.4758084322554237,
#  0.4887525562372188]

# %%
(np.array(f1_errs).mean(), np.array(f1_errs).std())
# Out:
# (0.48156364242613453, 0.005708914717441986)

# %% [markdown]
# ### **Creating the submission file**

# %%
test["pred"] = (
    np.mean(
        [
            (np.array(test_pred) >= fold_thresholds[test_pred_i]).astype(int)
            for test_pred_i, test_pred in enumerate(test_preds)
        ],
        axis=0,
    )
    >= 0.5
).astype(int)

# %%
sub = (
    samplesubmission.drop("ARTIS_DURUMU", 1)
    .merge(test[["POLICY_ID", "pred"]], how="left", on="POLICY_ID")
    .rename(columns={"pred": "ARTIS_DURUMU"})
)

# %%
sub.ARTIS_DURUMU.value_counts(normalize=True)
# Out:
# 0    0.917783
# 1    0.082217
# Name: ARTIS_DURUMU, dtype: float64

# %%
sub.shape
# Out:
# (243137, 2)

# %%
sub.head()
# Out:
#    POLICY_ID  ARTIS_DURUMU
# 0    6005558             0
# 1    1227288             0
# 2    5694750             0
# 3    3150098             0
# 4    4622228             0

# %%
sub.to_csv("submission.csv", index=False)
